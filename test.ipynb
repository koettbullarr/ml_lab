# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, mean_absolute_error, mean_squared_error
from sklearn import datasets
import matplotlib.pyplot as plt
from ml_lab import LinearRegression
# %matplotlib inline

# %%
def evaluate_regression(y_true, y_pred):
    return f"MAE: {mean_absolute_error(y_true, y_pred)}\nMSE: {mean_squared_error(y_true, y_pred)}\nRMSE: {np.sqrt(mean_squared_error(y_true, y_pred))}"

def evaluate_classification(y_true, y_pred):
    return f"{classification_report(y_true, y_pred)}\n{confusion_matrix(y_true, y_pred)}"

# %% [markdown]
# # Linear Regression

# %%
X, y = datasets.make_regression(n_samples=100, n_features=1, noise=20, random_state=123)
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=.2, random_state=123)

plt.figure(figsize=(8,4))
plt.scatter(X, y, color='black', marker='o')

# %%
lm = LinearRegression()
lm.fit(X_train,y_train)
pred = lm.predict(X_test)
print(evaluate_regression(y_test, pred))
# Out:
# MAE: 10.482303960068377
# MSE: 220.8253448122619
# RMSE: 14.860193296598194

# %%
plt.figure(figsize=(8,4))
plt.scatter(X, y, color='black', marker='o')
plt.plot(X, lm.predict(X))
